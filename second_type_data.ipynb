# %%
import pandas as pd
import json
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine

with open('./data.json') as json_file:
    data = json.load(json_file)

final_data = []
for each in data:
    filtered_data = each['content']['itemContent']['tweet_results']['result']['legacy']
    final_data.append(filtered_data)


df = pd.json_normalize(final_data)

df
# Out:
#                        created_at  conversation_id_str display_text_range  \
# 0  Fri May 25 13:14:39 +0000 2018  1000002204466597890           [0, 230]
# 1  Fri May 25 13:14:39 +0000 2018  1000002204466597890           [0, 230]
# 2  Fri May 25 13:14:39 +0000 2018  1000002204466597890           [0, 230]
# 3  Fri May 25 13:14:39 +0000 2018  1000002204466597890           [0, 230]
#
#    favorite_count  favorited  \
# 0               4      False
# 1               4      False
# 2               4      False
# 3               4      False
#
#                                            full_text  is_quote_status lang  \
# 0  🎉 "Mein Lotta-Leben" kommt ins Kino! 🎉 Wir fre...            False   de
# 1  🎉 "Mein Lotta-Leben" kommt ins Kino! 🎉 Wir fre...            False   de
# 2  🎉 "Mein Lotta-Leben" kommt ins Kino! 🎉 Wir fre...            False   de
# 3  🎉 "Mein Lotta-Leben" kommt ins Kino! 🎉 Wir fre...            False   de
#
# ...

# %%
conn_string = 'postgresql://postgres:1234@localhost/tweets'
db = create_engine(conn_string)
conn = db.connect()

# %%
df.to_sql('second_data', con=conn, if_exists='replace',
          index=False, dtype={"entities.media": sqlalchemy.types.JSON, "entities.urls": sqlalchemy.types.JSON, "extended_entities.media": sqlalchemy.types.JSON})
# Out:
# 4
