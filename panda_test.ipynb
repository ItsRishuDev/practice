# %%
import pandas as pd
import psycopg2
from sklearn import preprocessing
import sqlalchemy
from sqlalchemy import create_engine
from pyarrow import json
import pyarrow.parquet as pq

# %%
conn_string = 'postgresql://postgres:1234@localhost/test'
# conn_string = 'postgresql://username:password@host:port/test'
db = create_engine(conn_string)
conn = db.connect()

# %%
data = [
    {'created_at': 'Fri May 25 13:07:18 +0000 2018', 'id': 1000000355076399104, 'id_str': '1000000355076399104', 'full_text': 'Puro Talento Magangueleño https://t.co/uaU6b8I8IT', 'truncated': False, 'display_text_range': [0, 49], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/uaU6b8I8IT', 'expanded_url': 'https://www.facebook.com/mimagangue/videos/1754229747988631/', 'display_url': 'facebook.com/mimagangue/vid…', 'indices': [26, 49]}]}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user_id': 474004068, 'user_id_str': '474004068', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'reply_count': 0, 'quote_count': 0, 'conversation_id': 1000000355076399104, 'conversation_id_str': '1000000355076399104', 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_editable': True, 'lang': 'es', 'supplemental_language': None},
    {'created_at': 'Fri May 25 13:07:18 +0000 2018', 'id': 1000000355076399104, 'id_str': '1000000355076399104', 'full_text': 'Puro Talento Magangueleño https://t.co/uaU6b8I8IT', 'truncated': False, 'display_text_range': [0, 49], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/uaU6b8I8IT', 'expanded_url': 'https://www.facebook.com/mimagangue/videos/1754229747988631/', 'display_url': 'facebook.com/mimagangue/vid…', 'indices': [26, 49]}]}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user_id': 474004068, 'user_id_str': '474004068', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'reply_count': 0, 'quote_count': 0, 'conversation_id': 1000000355076399104, 'conversation_id_str': '1000000355076399104', 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_editable': True, 'lang': 'es', 'supplemental_language': None},
    {'created_at': 'Fri May 25 13:07:18 +0000 2018', 'id': 1000000355076399104, 'id_str': '1000000355076399104', 'full_text': 'Puro Talento Magangueleño https://t.co/uaU6b8I8IT', 'truncated': False, 'display_text_range': [0, 49], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/uaU6b8I8IT', 'expanded_url': 'https://www.facebook.com/mimagangue/videos/1754229747988631/', 'display_url': 'facebook.com/mimagangue/vid…', 'indices': [26, 49]}]}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user_id': 474004068, 'user_id_str': '474004068', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'reply_count': 0, 'quote_count': 0, 'conversation_id': 1000000355076399104, 'conversation_id_str': '1000000355076399104', 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_editable': True, 'lang': 'es', 'supplemental_language': None},
    {'created_at': 'Fri May 25 13:07:18 +0000 2018', 'id': 1000000355076399104, 'id_str': '1000000355076399104', 'full_text': 'Puro Talento Magangueleño https://t.co/uaU6b8I8IT', 'truncated': False, 'display_text_range': [0, 49], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/uaU6b8I8IT', 'expanded_url': 'https://www.facebook.com/mimagangue/videos/1754229747988631/', 'display_url': 'facebook.com/mimagangue/vid…', 'indices': [26, 49]}]}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user_id': 474004068, 'user_id_str': '474004068', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'reply_count': 0, 'quote_count': 0, 'conversation_id': 1000000355076399104, 'conversation_id_str': '1000000355076399104', 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_editable': True, 'lang': 'es', 'supplemental_language': None},
    {'created_at': 'Fri May 25 13:07:18 +0000 2018', 'id': 1000000355076399104, 'id_str': '1000000355076399104', 'full_text': 'Puro Talento Magangueleño https://t.co/uaU6b8I8IT', 'truncated': False, 'display_text_range': [0, 49], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/uaU6b8I8IT', 'expanded_url': 'https://www.facebook.com/mimagangue/videos/1754229747988631/', 'display_url': 'facebook.com/mimagangue/vid…', 'indices': [26, 49]}]}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user_id': 474004068, 'user_id_str': '474004068', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'reply_count': 0, 'quote_count': 0, 'conversation_id': 1000000355076399104, 'conversation_id_str': '1000000355076399104', 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_editable': True, 'lang': 'es', 'supplemental_language': None},
]

# df = pd.DataFrame(data)
# print(df)
# json_data = json.dumps(data)
# table = json.read_json(json_data) 
# pq.write_table(table)  # save json/table as parquet

df = pd.json_normalize(data)
df

# pq.write_table(data)
# Out:
#                        created_at                   id               id_str  \
# 0  Fri May 25 13:07:18 +0000 2018  1000000355076399104  1000000355076399104
# 1  Fri May 25 13:07:18 +0000 2018  1000000355076399104  1000000355076399104
# 2  Fri May 25 13:07:18 +0000 2018  1000000355076399104  1000000355076399104
# 3  Fri May 25 13:07:18 +0000 2018  1000000355076399104  1000000355076399104
# 4  Fri May 25 13:07:18 +0000 2018  1000000355076399104  1000000355076399104
#
#                                            full_text  truncated  \
# 0  Puro Talento Magangueleño https://t.co/uaU6b8I8IT      False
# 1  Puro Talento Magangueleño https://t.co/uaU6b8I8IT      False
# 2  Puro Talento Magangueleño https://t.co/uaU6b8I8IT      False
# 3  Puro Talento Magangueleño https://t.co/uaU6b8I8IT      False
# 4  Puro Talento Magangueleño https://t.co/uaU6b8I8IT      False
#
#   display_text_range                                             source  \
# ...

# %%
df.to_sql('testing_data_to_show', con=conn, if_exists='replace',
          index=False, dtype={"entities.urls": sqlalchemy.types.JSON},)
# Out:
# 5
